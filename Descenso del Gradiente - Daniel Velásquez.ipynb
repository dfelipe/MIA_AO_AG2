# %% [markdown]
# # AG2- Actividad Guiada 2 - Descenso del gradiente
#
# ## Daniel Velásquez
#
# ### Repositorio: https://github.com/dfelipe/MIA_AO_AG2

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import random

f=lambda X: X[0]**2+X[1]**2  # Función
df= lambda X: [2*X[0], 2*X[1]]   # Gradiente

resolucion = 100
rango = 2.5
X=np.linspace(-rango,rango,resolucion)
Y=np.linspace(-rango,rango,resolucion)
Z=np.zeros((resolucion,resolucion))
for ix, x in enumerate(X):
    for iy, y in enumerate(Y):
        Z[iy,ix]=f([x,y])
        
plt.contourf(X,Y,Z,resolucion)
plt.colorbar()

P=[random.uniform(-2,2),random.uniform(-2,2)]
print("Punto inicial: ",P)
plt.plot(P[0],P[1],"o",c="white")

#Tasa de aprendizaje
TA=.1

#Iteraciones
for _ in range(500):
    grad=df(P)
    P[0],P[1]= P[0] - TA*grad[0] , P[1] - TA*grad[1]
    plt.plot(P[0],P[1],"o",c="red")

plt.plot(P[0],P[1],"o",c="green")
plt.show()
print("Solución: ",P,f(P))
# Out:
# Punto inicial:  [-0.2656992078545448, 0.2377177570069242]
# Solución:  [-9.319309938508134e-50, 8.337870004668128e-50] 1.56369613944721e-98
